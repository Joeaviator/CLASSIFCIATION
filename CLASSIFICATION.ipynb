# %% [markdown]
# <a href="https://colab.research.google.com/github/Joeaviator/CLASSIFCIATION/blob/main/CLASSIFICATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from numpy import where
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.datasets import make_blobs

# %%
#Generate the data
x,y=make_blobs(n_samples=1000,centers=4,random_state=2)

# %%
#Understand the data
print(x.shape,y.shape)
# Out:
# (1000, 2) (1000,)

# %%
counter=Counter(y)
print(counter)
# Out:
# Counter({np.int64(2): 250, np.int64(1): 250, np.int64(0): 250, np.int64(3): 250})

# %%
#print the first ten samples
for i in range(10):
  print(x[i],y[i])
# Out:
# [-0.31332345 -4.25352048] 2
# [-2.68531026 -3.61156024] 2
# [-1.07861486 -3.40556561] 2
# [ 1.11104611 -1.83023746] 1
# [ 1.41707052 -1.10459115] 1
# [ -0.58498235 -11.51494191] 0
# [ 0.79040882 -0.62240538] 1
# [-2.1971023  -3.27748644] 2
# [-5.27570816  1.97451034] 3
# [-2.45274005 -2.02198311] 2

# %%
#Visualize the dataset
for label,_ in counter.items():
  #Get the Indeces
  row_ix=where(y==label)[0]
  plt.scatter(x[row_ix,0],x[row_ix,1], label=str(label))
#legend-key to describe the data
plt.legend()
plt.title("Classification example")
plt.show()
